# %% [markdown]
# # Python Control Structures
#
# **Instructions:** Review the online material at links below. Run the code blocks so the output for each code block shows in your notebook. Code blocks in the **Code Challenge** sections require you to enter code before you run it. You need to have the correct output showing for all code cells to receive full credit.
#
# ## Review If...Else
#
# Review the pages in the W3Schools __[Python If...Else](https://www.w3schools.com/python/python_conditions.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a variable age with the value 20
#
# Write an if statement that prints "Child" if age is less than 13
#
# Add an elif that prints "Teenager" if age is less than 18
#
# Add an else that prints "Adult"

# %%
age = 20

if age < 13:
  print("Child")
elif age <18:
  print("Teenager")
else:
  print("Adult")
# Out:
# Adult

# %% [markdown]
# ## Review Python Match
#
# Review the pages in the W3Schools __[Python Match](https://www.w3schools.com/python/python_match.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a variable day with the value 3
#
# Use a match statement to check the value of day
#
# Add a case 3 that prints "Wednesday"
#
# Add a wildcard case _ that prints "Other day"

# %%
# Create variable day
day = 3

# Use match statement
match day:
  case 3:
    print("Wednesday")
  case _:
    print("Other day")
# Out:
# Wednesday

# %% [markdown]
# ## Review Python While Loops
#
# Review the pages in the W3Schools __[Python While Loops](https://www.w3schools.com/python/python_while_loops.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a variable i with the value 0
#
# Write a while loop that runs as long as i is less than 6
#
# Inside the loop: increment i by 1
#
# If i equals 3, use continue to skip that iteration
#
# Print i

# %%
# Create the i variable
i = 0

# While loop: print 1-5, skip 3 with continue
while i < 6:
  i+=1
  if i == 3:
   continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# ## Review Python For Loops
#
# Review the pages in the W3Schools __[Python For Loops](https://www.w3schools.com/python/python_for_loops.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a list called fruits with: "apple", "banana", "cherry"
#
# Write a for loop that prints each item in fruits
#
# Use break to stop the loop when the item is "banana"

# %%
# Create the fruits list
fruits = ["apple", "banana", "cherry"]

# Loop through fruits, break at "banana"
for x in fruits:
  print(x)
  if x == "banana":
    break
# Out:
# apple
# banana

# %% [markdown]
# ## Submit Your Assignment
#
# * Add "_complete" to the end of the name of this notebook.
# * Save the notebook. (File - Save)
# * Download the notebook. (File - Download - Download .ipynb)
# * Upload your notebook to your GitHub repository. (__[Upload files to GitHub](https://github.com/cmcntsh/N6429_GitHubForClassAssignments#upload-files-directly-to-github)__)
# * Submit your repository link in Canvas.
