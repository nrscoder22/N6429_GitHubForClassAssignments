# %% [markdown]
# # Python Program Modularity
#
# **Instructions:** Review the online material at links below. Run the code blocks so the output for each code block shows in your notebook. Code blocks in the **Code Challenge** sections require you to enter code before you run it. You need to have the correct output showing for all code cells to receive full credit.
#
# ## Review Python Functions
#
# Review the pages in the W3Schools __[Python Functions](https://www.w3schools.com/python/python_functions.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a function called greet
#
# Add a parameter called name to the function
#
# Inside the function, print "Hello, " followed by the name parameter
#
# Call the function with the argument "Emil"

# %%
# Create the greet function
def greet(name):
  print("Hello, " + name)

# Call greet
greet("Emil")
# Out:
# Hello, Emil

# %% [markdown]
# ## Review Python Modules
#
# Review the pages in the W3Schools __[Python Modules](https://www.w3schools.com/python/python_modules.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Import the platform module
#
# Print the system platform using platform.system()

# %%
# Import the platform module
import platform

# Print the system platform
print(platform.system())
# Out:
# Linux

# %% [markdown]
# ## Review Python Dates
#
# Review the pages in the W3Schools __[Python Dates](https://www.w3schools.com/python/python_datetime.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Import the datetime module
#
# Store the current date and time in a variable called x
#
# Print the year from x

# %%
# Import the datetime module
import datetime

# Store the current date and time in x
x = datetime.datetime.now()

# Print the year
print(x.year)
# Out:
# 2026

# %% [markdown]
# ## Review Python JSON
#
# Review the pages in the W3Schools __[Python JSON](https://www.w3schools.com/python/python_json.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Import the json module
#
# Create a variable x with this JSON string: '{"name": "Emil", "age": 30}'
#
# Convert the JSON string into a Python dictionary and store it in y
#
# Print the age from y

# %%
# Import json
import json

# Create a JSON string
x = '{"name": "Emil", "age": 30}'

# Parse the JSON string
y = json.loads(x)

# Print the age
print(y["age"])
# Out:
# 30

# %% [markdown]
# ## Review Python PIP
#
# Review the pages in the __[Python PIP](https://www.w3schools.com/python/python_pip.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Check to see if PIP is installed (You need to run the code in the terminal.)
#
# If PIP is not installed, install PIP (You need to run the code in the terminal.)
#
# Use PIP to install the package pypdf (You need to run the code in the terminal. This is a common package for extracting text from PDF documents using Python.)

# %%
# Check to see if PIP is install!pip --version
# !pip --version

# Install PIP if needed

# Install the pypdf package
# !pip install pypdf
# Out:
# pip 24.1.2 from /usr/local/lib/python3.13/dist-packages/pip (python 3.13)
# ...

# %% [markdown]
# ## Review Python RegEx
#
# Review the pages in the __[Python RegEx](https://www.w3schools.com/python/python_regex.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Import the re module
#
# Create a variable txt with the value "The rain in Spain"
#
# Search for "Spain" in txt and store the result in x
#
# Print the position (span) of the match

# %%
# Import re
import re

# Create a string
txt = "The rain in Spain"

# Search for "Spain"
x = re.search("Spain", txt)

# Print the span
print(x.span())
# Out:
# (12, 17)

# %% [markdown]
# ## The Python Standard Library Official Reference Page
#
# The W3 School tutorial highlights several packages from the Python Standard Library. (datetime, math, JSON, re)
#
# Visit the __[Python Standard Library](https://docs.python.org/3/library/index.html)__ reference page.
#
# There are **MANY** packages in the Python Standard Library besides those highlighted by the W3 School tutorials. Search the Python Standard Library reference page for the packages mentioned above. (Hint: It's probably fastest to use ctrl-f to search the page for the text you're looking for.)
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# List the heading under which you found each of the packages in the comments below.

# %%
# datetime heading:
#Data Types

# math heading:
#Numeric and Mathematical Modules

# json heading:
#Internet Data Handling

# re heading:
#Text Processing Services

# %% [markdown]
# ## Submit Your Assignment
#
# * Add "_complete" to the end of the name of this notebook.
# * Save the notebook. (File - Save)
# * Download the notebook. (File - Download - Download .ipynb)
# * Upload your notebook to your GitHub repository. (__[Upload files to GitHub](https://github.com/cmcntsh/N6429_GitHubForClassAssignments#upload-files-directly-to-github)__)
# * Submit your repository link in Canvas.
